# %%
from oqd_core.analysis.analog.cfg import AnalogCFGBuilder, Accumulator
from oqd_core.frontend.analog import parse_analog

source = """ 
x = 0
while (true) {
    x = x + 2
    if (x > 3) {
        break
    }
}
"""
source = """ 
a = 1
if (a > 1) {
    a = a + 2
}
else {
    a = a + 3
}
a
"""
# source = "if (5 == 2) { \n a = 1}"
# source = "a = 1"
source = """ 
a = 1
b = 2
r = qreg(3)
p = 4
d = sin(3.141592)
"""
# source = """ 

# a = 2
# b = 3
# if (a > 2) {
#     a = 3
#     if (a==b) {
#         b = 2
#     }
#     else {
#         b = 5
#     }
#     if (b < a) {
#         b = 5
#     }
# }
# c = a + b
# c
# """
# source = "if (5 == 2) { \n a = 1}"
# source = """ 
# a = 1
# while (true) {
#     a = a + 1
#     if (a > 2) {
#         break
#     }
# }
# """
source = """ 
x = 0
while (true) {
    x = x + 2
    if (x > 3) {
        break
    }
    else {
        a = 1
    }
    
}

"""
with open("test.analog", mode="r", encoding="utf8") as f:
    source = f.read()

# source = """ 
# a = 5
# b = 3
# if (a > b) {
#     if (b > 0) {
#         initialize(targets)
#     }
#     else {
#         measure(r)
#     }
# }
# """
circuit = parse_analog(source)

# %%
circuit
# Out:
# AnalogCircuit(class_='AnalogCircuit', statements=[Declaration(class_='Declaration', name='r', value=QuantumRegister(class_='QuantumRegister', size=2)), Declaration(class_='Declaration', name='s', value=ModeRegister(class_='ModeRegister', size=3)), Declaration(class_='Declaration', name='q0', value=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=0)), Declaration(class_='Declaration', name='q1', value=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=1)), Declaration(class_='Declaration', name='targets', value=AnalogList(class_='AnalogList', values=[Access(class_='Access', name='q0'), Access(class_='Access', name='q1')])), Declaration(class_='Declaration', name='pi', value=MathNum(class_='MathNum', value=3.14159)), Declaration(class_='Declaration', name='tau', value=MathMul(class_='MathMul', expr1=MathNum(class_='MathNum', value=2), expr2=Access(class_='Access', name='pi'))), Declaration(class_='Declaration', name='omega', value=MathVar(class_='MathVar', name='#omega')), Declaration(class_='Declaration', name='phase', value=MathAdd(class_='MathAdd', expr1=MathMul(class_='MathMul', expr1=MathVar(class_='MathVar', name='#t'), expr2=Access(class_='Access', name='omega')), expr2=MathVar(class_='MathVar', name='#phi'))), Declaration(class_='Declaration', name='neg', value=MathMul(class_='MathMul', expr1=MathNum(class_='MathNum', value=-1), expr2=MathNum(class_='MathNum', value=1))), Declaration(class_='Declaration', name='cubed', value=MathPow(class_='MathPow', expr1=MathNum(class_='MathNum', value=2), expr2=MathNum(class_='MathNum', value=3))), Declaration(class_='Declaration', name='sine', value=MathFunc(class_='MathFunc', func='sin', expr=MathNum(class_='MathNum', value=0.5))), Declaration(class_='Declaration', name='cosed', value=MathFunc(class_='MathFunc', func='cos', expr=Access(class_='Access', name='phase'))), Declaration(class_='Declaration', name='cplx', value=MathAdd(class_='MathAdd', expr1=MathNum(class_='MathNum', value=1.0), expr2=MathMul(class_='MathMul', expr1=MathImag(class_='MathImag'), expr2=MathNum(class_='MathNum', value=0.5)))), Declaration(class_='Declaration', name='X', value=PauliX(class_='PauliX')), Declaration(class_='Declaration', name='Y', value=PauliY(class_='PauliY')), Declaration(class_='Declaration', name='Z', value=PauliZ(class_='PauliZ')), Declaration(class_='Declaration', name='I', value=PauliI(class_='PauliI')), Declaration(class_='Declaration', name='C', value=Creation(class_='Creation')), Declaration(class_='Declaration', name='A', value=Annihilation(class_='Annihilation')), Declaration(class_='Declaration', name='J', value=Identity(class_='Identity')), Declaration(class_='Declaration', name='H_single', value=OperatorAdd(class_='OperatorAdd', op1=OperatorMul(class_='OperatorMul', op1=MathNum(class_='MathNum', value=0.5), op2=PauliX(class_='PauliX')), op2=OperatorMul(class_='OperatorMul', op1=MathNum(class_='MathNum', value=0.5), op2=PauliZ(class_='PauliZ')))), Declaration(class_='Declaration', name='H_pair', value=OperatorAdd(class_='OperatorAdd', op1=OperatorKron(class_='OperatorKron', op1=PauliX(class_='PauliX'), op2=PauliI(class_='PauliI')), op2=OperatorKron(class_='OperatorKron', op1=PauliI(class_='PauliI'), op2=PauliX(class_='PauliX')))), Declaration(class_='Declaration', name='H_rabi', value=OperatorAdd(class_='OperatorAdd', op1=OperatorMul(class_='OperatorMul', op1=MathMul(class_='MathMul', expr1=MathNum(class_='MathNum', value=0.5), expr2=MathVar(class_='MathVar', name='#t')), op2=OperatorKron(class_='OperatorKron', op1=PauliX(class_='PauliX'), op2=PauliI(class_='PauliI'))), op2=OperatorMul(class_='OperatorMul', op1=MathNum(class_='MathNum', value=0.5), op2=OperatorKron(class_='OperatorKron', op1=PauliI(class_='PauliI'), op2=PauliY(class_='PauliY'))))), Declaration(class_='Declaration', name='x', value=MathNum(class_='MathNum', value=1)), IfElse(class_='IfElse', condition=BoolGreaterThan(class_='BoolGreaterThan', expr1=Access(class_='Acce ...

# %%
cfg = AnalogCFGBuilder().run(circuit)
# print(cfg.blocks)
cfg = Accumulator()(cfg)
# cfg = builder.run(circuit)
# builder.blocks
# cfg.blocks

# %%
cfg.to_dict()
# Out:
# {0: {'register_id': 0,
#   'stmts': [{}],
#   'preds': [],
#   'succs': [1],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  1: {'register_id': 1,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'r',
#     'value': {'class_': 'QuantumRegister', 'size': 2}},
#    {'class_': 'Declaration',
#     'name': 's',
#     'value': {'class_': 'ModeRegister', 'size': 3}},
#    {'class_': 'Declaration',
#     'name': 'q0',
#     'value': {'class_': 'Extract',
#      'access': {'class_': 'Access', 'name': 'r'},
#      'index': 0}},
#    {'class_': 'Declaration',
#     'name': 'q1',
#     'value': {'class_': 'Extract',
#      'access': {'class_': 'Access', 'name': 'r'},
#      'index': 1}},
#    {'class_': 'Declaration',
#     'name': 'targets',
#     'value': {'class_': 'AnalogList',
#      'values': [{'class_': 'Access', 'name': 'q0'},
#       {'class_': 'Access', 'name': 'q1'}]}},
#    {'class_': 'Declaration',
#     'name': 'pi',
#     'value': {'class_': 'MathNum', 'value': 3.14159}},
#    {'class_': 'Declaration',
#     'name': 'tau',
#     'value': {'class_': 'MathMul',
#      'expr1': {'class_': 'MathNum', 'value': 2},
#      'expr2': {'class_': 'Access', 'name': 'pi'}}},
#    {'class_': 'Declaration',
#     'name': 'omega',
#     'value': {'class_': 'MathVar', 'name': '#omega'}},
#    {'class_': 'Declaration',
#     'name': 'phase',
#     'value': {'class_': 'MathAdd',
#      'expr1': {'class_': 'MathMul',
#       'expr1': {'class_': 'MathVar', 'name': '#t'},
#       'expr2': {'class_': 'Access', 'name': 'omega'}},
#      'expr2': {'class_': 'MathVar', 'name': '#phi'}}},
#    {'class_': 'Declaration',
#     'name': 'neg',
#     'value': {'class_': 'MathMul',
#      'expr1': {'class_': 'MathNum', 'value': -1},
#      'expr2': {'class_': 'MathNum', 'value': 1}}},
#    {'class_': 'Declaration',
#     'name': 'cubed',
#     'value': {'class_': 'MathPow',
#      'expr1': {'class_': 'MathNum', 'value': 2},
#      'expr2': {'class_': 'MathNum', 'value': 3}}},
#    {'class_': 'Declaration',
#     'name': 'sine',
#     'value': {'class_': 'MathFunc',
#      'func': 'sin',
#      'expr': {'class_': 'MathNum', 'value': 0.5}}},
#    {'class_': 'Declaration',
#     'name': 'cosed',
#     'value': {'class_': 'MathFunc',
#      'func': 'cos',
#      'expr': {'class_': 'Access', 'name': 'phase'}}},
#    {'class_': 'Declaration',
#     'name': 'cplx',
#     'value': {'class_': 'MathAdd',
#      'expr1': {'class_': 'MathNum', 'value': 1.0},
#      'expr2': {'class_': 'MathMul',
#       'expr1': {'class_': 'MathImag'},
#       'expr2': {'class_': 'MathNum', 'value': 0.5}}}},
#    {'class_': 'Declaration', 'name': 'X', 'value': {'class_': 'PauliX'}},
#    {'class_': 'Declaration', 'name': 'Y', 'value': {'class_': 'PauliY'}},
#    {'class_': 'Declaration', 'name': 'Z', 'value': {'class_': 'PauliZ'}},
#    {'class_': 'Declaration', 'name': 'I', 'value': {'class_': 'PauliI'}},
#    {'class_': 'Declaration', 'name': 'C', 'value': {'class_': 'Creation'}},
#    {'class_': 'Declaration', 'name': 'A', 'value': {'class_': 'Annihilation'}},
#    {'class_': 'Declaration', 'name': 'J', 'value': {'class_': 'Identity'}},
#    {'class_': 'Declaration',
#     'name': 'H_single',
#     'value': {'class_': 'OperatorAdd',
#      'op1': {'class_': 'OperatorMul',
#       'op1': {'class_': 'MathNum', 'value': 0.5},
#       'op2': {'class_': 'PauliX'}},
#      'op2': {'class_': 'OperatorMul',
#       'op1': {'class_': 'MathNum', 'value': 0.5},
#       'op2': {'class_': 'PauliZ'}}}},
#    {'class_': 'Declaration',
#     'name': 'H_pair',
#     'value': {'class_': 'OperatorAdd',
#      'op1': {'class_': 'OperatorKron',
#       'op1': {'class_': 'PauliX'},
#       'op2': {'class_': 'PauliI'}},
#      'op2': {'class_': 'OperatorKron',
#       'op1': {'class_': 'PauliI'},
#       'op2': {'class_': 'PauliX'}}}},
#    {'class_': 'Declaration',
#     'name': 'H_rabi',
#     'value': {'class_': 'OperatorAdd',
#      'op1': {'class_': 'OperatorMul',
#       'op1': {'class_': 'MathMul',
#        'expr1': {'class_': 'MathNum', 'value': 0.5},
#        'expr2': {'class_': 'MathVar', 'name': '#t'}},
#       'op2': {'class_': 'OperatorKron',
#        'op1': {'class_': 'PauliX'},
#        'op2': {'class_': 'PauliI'}}},
#      'op2': {'class_': 'OperatorMul',
#       'op1': {'class_': 'MathNum', 'value': 0.5},
#       'op2': {'class_': 'OperatorKron',
#        'op1': {'class_': 'PauliI'},
#        'op2': {'class_': 'PauliY'}}}}},
#    {'class_': 'Declaration',
#     'name': 'x',
#     'value': {'class_': 'MathNum', 'value': 1}}],
#   'preds': [0],
#   'succs': [26],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  26: {'register_id': 26,
#   'stmts': [{'class_': 'BoolGreaterThan',
#     'expr1': {'class_': 'Access', 'name': 'x'},
#     'expr2': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [1],
#   'succs': [27, 28],
#   'exit_nodes': [],
#   'edge_labels': {27: 'true', 28: 'false'}},
#  27: {'register_id': 27,
#   'stmts': [{'class_': 'Initialize',
#     'targets': {'class_': 'Access', 'name': 'r'}}],
#   'preds': [26],
#   'succs': [28],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  28: {'register_id': 28,
#   'stmts': [{'class_': 'BoolEq',
#     'expr1': {'class_': 'Access', 'name': 'x'},
#     'expr2': {'class_': 'MathNum', 'value': 1}}],
#   'preds': [27, 26],
#   'succs': [29, 30],
#   'exit_nodes': [],
#   'edge_labels': {29: 'true', 30: 'false'}},
#  29: {'register_id': 29,
#   'stmts': [{'class_': 'Evolve',
#     'hamiltonian': {'class_': 'Access', 'name': 'H_single'},
#     'duration': {'class_': 'MathNum', 'value': 1.0},
#     'targets': {'class_': 'Extract',
#      'access': {'class_': 'Access', 'name': 'r'},
#      'index': 0}}],
#   'preds': [28],
#   'succs': [31],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  30: {'register_id': 30,
#   'stmts': [{'class_': 'Evolve',
#     'hamiltonian': {'class_': 'Access', 'name': 'H_pair'},
#     'duration': {'class_': 'MathNum', 'value': 0.5},
#     'targets': {'class_': 'Access', 'name': 'r'}}],
#   'preds': [28],
#   'succs': [31],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  31: {'register_id': 31,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'n',
#     'value': {'class_': 'MathNum', 'value': 3}}],
#   'preds': [29, 30],
#   'succs': [32],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  32: {'register_id': 32,
#   'stmts': [{'class_': 'BoolGreaterThan',
#     'expr1': {'class_': 'Access', 'name': 'n'},
#     'expr2': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [31, 33],
#   'succs': [33, 35],
#   'exit_nodes': [],
#   'edge_labels': {33: 'true', 35: 'false'}},
#  33: {'register_id': 33,
#   'stmts': [{'class_': 'Evolve',
#     'hamiltonian': {'class_': 'Access', 'name': 'H_rabi'},
#     'duration': {'class_': 'MathNum', 'value': 0.1},
#     'targets': {'class_': 'Access', 'name': 'targets'}},
#    {'class_': 'Declaration',
#     'name': 'n',
#     'value': {'class_': 'MathSub',
#      'expr1': {'class_': 'Access', 'name': 'n'},
#      'expr2': {'class_': 'MathNum', 'value': 1}}}],
#   'preds': [32],
#   'succs': [32],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  35: {'register_id': 35,
#   'stmts': [{'class_': 'Bool', 'value': True}],
#   'preds': [32, 36],
#   'succs': [36, 38],
#   'exit_nodes': [37],
#   'edge_labels': {36: 'true', 38: 'false'}},
#  36: {'register_id': 36,
#   'stmts': [{'class_': 'BoolEq',
#     'expr1': {'class_': 'Access', 'name': 'x'},
#     'expr2': {'class_': 'MathNum', 'value': 1}}],
#   'preds': [35],
#   'succs': [37, 35],
#   'exit_nodes': [],
#   'edge_labels': {37: 'true', 35: 'false'}},
#  37: {'register_id': 37,
#   'stmts': [{'class_': 'Break'}],
#   'preds': [36],
#   'succs': [38],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  38: {'register_id': 38,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'a',
#     'value': {'class_': 'MathNum', 'value': 5}},
#    {'class_': 'Declaration',
#     'name': 'b',
#     'value': {'class_': 'MathNum', 'value': 3}}],
#   'preds': [37, 35],
#   'succs': [40],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  40: {'register_id': 40,
#   'stmts': [{'class_': 'BoolGreaterThan',
#     'expr1': {'class_': 'Access', 'name': 'a'},
#     'expr2': {'class_': 'Access', 'name': 'b'}}],
#   'preds': [38],
#   'succs': [41, 44],
#   'exit_nodes': [],
#   'edge_labels': {41: 'true', 44: 'false'}},
#  41: {'register_id': 41,
#   'stmts': [{'class_': 'BoolGreaterThan',
#     'expr1': {'class_': 'Access', 'name': 'b'},
#     'expr2': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [40],
#   'succs': [42, 43],
#   'exit_nodes': [],
#   'edge_labels': {42: 'true', 43: 'false'}},
#  42: {'register_id': 42,
#   'stmts': [{'class_': 'Initialize',
#     'targets': {'class_': 'Access', 'name': 'targets'}}],
#   'preds': [41],
#   'succs': [44],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  43: {'register_id': 43,
#   'stmts': [{'class_': 'Measure',
#     'targets': {'class_': 'Access', 'name': 'r'}}],
#   'preds': [41],
#   'succs': [44],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  44: {'register_id': 44,
#   'stmts': [{'class_': 'Initialize',
#     'targets': {'class_': 'Access', 'name': 'r'}},
#    {'class_': 'Evolve',
#     'hamiltonian': {'class_': 'Access', 'name': 'H_single'},
#     'duration': {'class_': 'MathNum', 'value': 2.0},
#     'targets': {'class_': 'Access', 'name': 'q1'}},
#    {'class_': 'Evolve',
#     'hamiltonian': {'class_': 'Access', 'name': 'H_pair'},
#     'duration': {'class_': 'MathNum', 'value': 1.0},
#     'targets': {'class_': 'Access', 'name': 'targets'}},
#    {'class_': 'Evolve',
#     'hamiltonian': {'class_': 'OperatorMul',
#      'op1': {'class_': 'PauliX'},
#      'op2': {'class_': 'MathNum', 'value': 0.5}},
#     'duration': {'class_': 'Access', 'name': 'pi'},
#     'targets': {'class_': 'Access', 'name': 'q0'}},
#    {'class_': 'Measure', 'targets': {'class_': 'Access', 'name': 'r'}},
#    {'class_': 'Declaration',
#     'name': 'measurement',
#     'value': {'class_': 'Measure',
#      'targets': {'class_': 'Access', 'name': 'q0'}}},
#    {'class_': 'Declaration',
#     'name': 'flag',
#     'value': {'class_': 'MathNum', 'value': 1}}],
#   'preds': [42, 43, 40],
#   'succs': [51],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  51: {'register_id': 51,
#   'stmts': [{'class_': 'BoolNotEq',
#     'expr1': {'class_': 'Access', 'name': 'flag'},
#     'expr2': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [44],
#   'succs': [52, 53],
#   'exit_nodes': [],
#   'edge_labels': {52: 'true', 53: 'false'}},
#  52: {'register_id': 52,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'x',
#     'value': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [51],
#   'succs': [53],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  53: {'register_id': 53,
#   'stmts': [{'class_': 'BoolLessThanEq',
#     'expr1': {'class_': 'Access', 'name': 'x'},
#     'expr2': {'class_': 'MathNum', 'value': 1}}],
#   'preds': [52, 51],
#   'succs': [54, 55],
#   'exit_nodes': [],
#   'edge_labels': {54: 'true', 55: 'false'}},
#  54: {'register_id': 54,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'x',
#     'value': {'class_': 'MathNum', 'value': 1}}],
#   'preds': [53],
#   'succs': [55],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  55: {'register_id': 55,
#   'stmts': [{'class_': 'BoolGreaterThanEq',
#     'expr1': {'class_': 'Access', 'name': 'x'},
#     'expr2': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [54, 53],
#   'succs': [56, 57],
#   'exit_nodes': [],
#   'edge_labels': {56: 'true', 57: 'false'}},
#  56: {'register_id': 56,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'x',
#     'value': {'class_': 'MathNum', 'value': 0}}],
#   'preds': [55],
#   'succs': [57],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  57: {'register_id': 57,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'a',
#     'value': {'class_': 'Bool', 'value': True}}],
#   'preds': [56, 55],
#   'succs': [58],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  58: {'register_id': 58,
#   'stmts': [{'class_': 'Access', 'name': 'a'}],
#   'preds': [57],
#   'succs': [59, 60],
#   'exit_nodes': [],
#   'edge_labels': {59: 'true', 60: 'false'}},
#  59: {'register_id': 59,
#   'stmts': [{'class_': 'Declaration',
#     'name': 'b',
#     'value': {'class_': 'MathNum', 'value': 5}}],
#   'preds': [58],
#   'succs': [60],
#   'exit_nodes': [],
#   'edge_labels': {}},
#  60: {'register_id': 60,
#   'stmts': [{}],
#   'preds': [59, 58],
#   'succs': [],
#   'exit_nodes': [],
#   'edge_labels': {}}}
