# %%
from oqd_compiler_infrastructure import CFGBlockAccumulator

from oqd_core.analysis.analog.cfg import AnalogCFGBuilder
from oqd_core.frontend.analog import parse_analog

source = """ 
x = 0
while (true) {
    x = x + 2
    if (x > 3) {
        break
    }
}
"""
source = """ 
a = 1
if (a > 1) {
    a = a + 2
}
else {
    a = a + 3
}
a
"""
# source = "if (5 == 2) { \n a = 1}"
# source = "a = 1"
source = """ 
a = 1
b = 2
r = qreg(3)
p = 4
d = sin(3.141592)
"""
# source = """

# a = 2
# b = 3
# if (a > 2) {
#     a = 3
#     if (a==b) {
#         b = 2
#     }
#     else {
#         b = 5
#     }
#     if (b < a) {
#         b = 5
#     }
# }
# c = a + b
# c
# """
# source = "if (5 == 2) { \n a = 1}"
# source = """
# a = 1
# while (true) {
#     a = a + 1
#     if (a > 2) {
#         break
#     }
# }
# """
source = """ 
x = 0
y = 2
z = 3

while (true) {
    x = x + 2
    if (x > 3) {
        break
    }
    else {
        a = 1
    }
    
}

"""
with open("test.analog", mode="r", encoding="utf8") as f:
    source = f.read()

# source = """
# a = 5
# b = 3
# if (a > b) {
#     if (b > 0) {
#         initialize(targets)
#     }
#     else {
#         measure(r)
#     }
# }
# """
circuit = parse_analog(source)

# %%
circuit
# Out:
# AnalogCircuit(class_='AnalogCircuit', statements=[Declaration(class_='Declaration', name='r', value=QuantumRegister(class_='QuantumRegister', size=2)), Declaration(class_='Declaration', name='s', value=ModeRegister(class_='ModeRegister', size=3)), Declaration(class_='Declaration', name='q0', value=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=0)), Declaration(class_='Declaration', name='q1', value=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=1)), Declaration(class_='Declaration', name='targets', value=AnalogList(class_='AnalogList', values=[Access(class_='Access', name='q0'), Access(class_='Access', name='q1')])), Declaration(class_='Declaration', name='pi', value=MathNum(class_='MathNum', value=3.14159)), Declaration(class_='Declaration', name='tau', value=MathMul(class_='MathMul', expr1=MathNum(class_='MathNum', value=2), expr2=Access(class_='Access', name='pi'))), Declaration(class_='Declaration', name='omega', value=MathVar(class_='MathVar', name='#omega')), Declaration(class_='Declaration', name='phase', value=MathAdd(class_='MathAdd', expr1=MathMul(class_='MathMul', expr1=MathVar(class_='MathVar', name='#t'), expr2=Access(class_='Access', name='omega')), expr2=MathVar(class_='MathVar', name='#phi'))), Declaration(class_='Declaration', name='neg', value=MathMul(class_='MathMul', expr1=MathNum(class_='MathNum', value=-1), expr2=MathNum(class_='MathNum', value=1))), Declaration(class_='Declaration', name='cubed', value=MathPow(class_='MathPow', expr1=MathNum(class_='MathNum', value=2), expr2=MathNum(class_='MathNum', value=3))), Declaration(class_='Declaration', name='sine', value=MathFunc(class_='MathFunc', func='sin', expr=MathNum(class_='MathNum', value=0.5))), Declaration(class_='Declaration', name='cosed', value=MathFunc(class_='MathFunc', func='cos', expr=Access(class_='Access', name='phase'))), Declaration(class_='Declaration', name='cplx', value=MathAdd(class_='MathAdd', expr1=MathNum(class_='MathNum', value=1.0), expr2=MathMul(class_='MathMul', expr1=MathImag(class_='MathImag'), expr2=MathNum(class_='MathNum', value=0.5)))), Declaration(class_='Declaration', name='X', value=PauliX(class_='PauliX')), Declaration(class_='Declaration', name='Y', value=PauliY(class_='PauliY')), Declaration(class_='Declaration', name='Z', value=PauliZ(class_='PauliZ')), Declaration(class_='Declaration', name='I', value=PauliI(class_='PauliI')), Declaration(class_='Declaration', name='C', value=Creation(class_='Creation')), Declaration(class_='Declaration', name='A', value=Annihilation(class_='Annihilation')), Declaration(class_='Declaration', name='J', value=Identity(class_='Identity')), Declaration(class_='Declaration', name='H_single', value=OperatorAdd(class_='OperatorAdd', op1=OperatorMul(class_='OperatorMul', op1=MathNum(class_='MathNum', value=0.5), op2=PauliX(class_='PauliX')), op2=OperatorMul(class_='OperatorMul', op1=MathNum(class_='MathNum', value=0.5), op2=PauliZ(class_='PauliZ')))), Declaration(class_='Declaration', name='H_pair', value=OperatorAdd(class_='OperatorAdd', op1=OperatorKron(class_='OperatorKron', op1=PauliX(class_='PauliX'), op2=PauliI(class_='PauliI')), op2=OperatorKron(class_='OperatorKron', op1=PauliI(class_='PauliI'), op2=PauliX(class_='PauliX')))), Declaration(class_='Declaration', name='H_rabi', value=OperatorAdd(class_='OperatorAdd', op1=OperatorMul(class_='OperatorMul', op1=MathMul(class_='MathMul', expr1=MathNum(class_='MathNum', value=0.5), expr2=MathVar(class_='MathVar', name='#t')), op2=OperatorKron(class_='OperatorKron', op1=PauliX(class_='PauliX'), op2=PauliI(class_='PauliI'))), op2=OperatorMul(class_='OperatorMul', op1=MathNum(class_='MathNum', value=0.5), op2=OperatorKron(class_='OperatorKron', op1=PauliI(class_='PauliI'), op2=PauliY(class_='PauliY'))))), Declaration(class_='Declaration', name='x', value=MathNum(class_='MathNum', value=1)), IfElse(class_='IfElse', condition=BoolGreaterThan(class_='BoolGreaterThan', expr1=Access(class_='Acce ...

# %%
cfg = AnalogCFGBuilder()(circuit)
# print(cfg.blocks)
cfg = CFGBlockAccumulator()(cfg)
# cfg = builder.run(circuit)
# builder.blocks
# cfg.blocks

# %%
from rich import print as pprint

pprint(cfg.blocks)
# Out:
# {
#     0: CFGBlock(register_id=0, stmts=[], preds=[], succs=[1], exit_nodes=[], edge_labels={}),
#     1: CFGBlock(
#         register_id=1,
#         stmts=[
#             Declaration(class_='Declaration', name='r', value=QuantumRegister(class_='QuantumRegister', size=2)),
#             Declaration(class_='Declaration', name='s', value=ModeRegister(class_='ModeRegister', size=3)),
#             Declaration(
#                 class_='Declaration',
#                 name='q0',
#                 value=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=0)
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='q1',
#                 value=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=1)
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='targets',
#                 value=AnalogList(
#                     class_='AnalogList',
#                     values=[Access(class_='Access', name='q0'), Access(class_='Access', name='q1')]
#                 )
#             ),
#             Declaration(class_='Declaration', name='pi', value=MathNum(class_='MathNum', value=3.14159)),
#             Declaration(
#                 class_='Declaration',
#                 name='tau',
#                 value=MathMul(
#                     class_='MathMul',
#                     expr1=MathNum(class_='MathNum', value=2),
#                     expr2=Access(class_='Access', name='pi')
#                 )
#             ),
#             Declaration(class_='Declaration', name='omega', value=MathVar(class_='MathVar', name='#omega')),
#             Declaration(
#                 class_='Declaration',
#                 name='phase',
#                 value=MathAdd(
#                     class_='MathAdd',
#                     expr1=MathMul(
#                         class_='MathMul',
#                         expr1=MathVar(class_='MathVar', name='#t'),
#                         expr2=Access(class_='Access', name='omega')
#                     ),
#                     expr2=MathVar(class_='MathVar', name='#phi')
#                 )
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='neg',
#                 value=MathMul(
#                     class_='MathMul',
#                     expr1=MathNum(class_='MathNum', value=-1),
#                     expr2=MathNum(class_='MathNum', value=1)
#                 )
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='cubed',
#                 value=MathPow(
#                     class_='MathPow',
#                     expr1=MathNum(class_='MathNum', value=2),
#                     expr2=MathNum(class_='MathNum', value=3)
#                 )
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='sine',
#                 value=MathFunc(class_='MathFunc', func='sin', expr=MathNum(class_='MathNum', value=0.5))
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='cosed',
#                 value=MathFunc(class_='MathFunc', func='cos', expr=Access(class_='Access', name='phase'))
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='cplx',
#                 value=MathAdd(
#                     class_='MathAdd',
#                     expr1=MathNum(class_='MathNum', value=1.0),
#                     expr2=MathMul(
#                         class_='MathMul',
#                         expr1=MathImag(class_='MathImag'),
#                         expr2=MathNum(class_='MathNum', value=0.5)
#                     )
#                 )
#             ),
#             Declaration(class_='Declaration', name='X', value=PauliX(class_='PauliX')),
#             Declaration(class_='Declaration', name='Y', value=PauliY(class_='PauliY')),
#             Declaration(class_='Declaration', name='Z', value=PauliZ(class_='PauliZ')),
#             Declaration(class_='Declaration', name='I', value=PauliI(class_='PauliI')),
#             Declaration(class_='Declaration', name='C', value=Creation(class_='Creation')),
#             Declaration(class_='Declaration', name='A', value=Annihilation(class_='Annihilation')),
#             Declaration(class_='Declaration', name='J', value=Identity(class_='Identity')),
#             Declaration(
#                 class_='Declaration',
#                 name='H_single',
#                 value=OperatorAdd(
#                     class_='OperatorAdd',
#                     op1=OperatorMul(
#                         class_='OperatorMul',
#                         op1=MathNum(class_='MathNum', value=0.5),
#                         op2=PauliX(class_='PauliX')
#                     ),
#                     op2=OperatorMul(
#                         class_='OperatorMul',
#                         op1=MathNum(class_='MathNum', value=0.5),
#                         op2=PauliZ(class_='PauliZ')
#                     )
#                 )
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='H_pair',
#                 value=OperatorAdd(
#                     class_='OperatorAdd',
#                     op1=OperatorKron(
#                         class_='OperatorKron',
#                         op1=PauliX(class_='PauliX'),
#                         op2=PauliI(class_='PauliI')
#                     ),
#                     op2=OperatorKron(
#                         class_='OperatorKron',
#                         op1=PauliI(class_='PauliI'),
#                         op2=PauliX(class_='PauliX')
#                     )
#                 )
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='H_rabi',
#                 value=OperatorAdd(
#                     class_='OperatorAdd',
#                     op1=OperatorMul(
#                         class_='OperatorMul',
#                         op1=MathMul(
#                             class_='MathMul',
#                             expr1=MathNum(class_='MathNum', value=0.5),
#                             expr2=MathVar(class_='MathVar', name='#t')
#                         ),
#                         op2=OperatorKron(
#                             class_='OperatorKron',
#                             op1=PauliX(class_='PauliX'),
#                             op2=PauliI(class_='PauliI')
#                         )
#                     ),
#                     op2=OperatorMul(
#                         class_='OperatorMul',
#                         op1=MathNum(class_='MathNum', value=0.5),
#                         op2=OperatorKron(
#                             class_='OperatorKron',
#                             op1=PauliI(class_='PauliI'),
#                             op2=PauliY(class_='PauliY')
#                         )
#                     )
#                 )
#             ),
#             Declaration(class_='Declaration', name='x', value=MathNum(class_='MathNum', value=1))
#         ],
#         preds=[0],
#         succs=[26],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     26: CFGBlock(
#         register_id=26,
#         stmts=[
#             BoolGreaterThan(
#                 class_='BoolGreaterThan',
#                 expr1=Access(class_='Access', name='x'),
#                 expr2=MathNum(class_='MathNum', value=0)
#             )
#         ],
#         preds=[1],
#         succs=[27, 28],
#         exit_nodes=[],
#         edge_labels={27: 'true', 28: 'false'}
#     ),
#     27: CFGBlock(
#         register_id=27,
#         stmts=[Initialize(class_='Initialize', targets=Access(class_='Access', name='r'))],
#         preds=[26],
#         succs=[28],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     28: CFGBlock(
#         register_id=28,
#         stmts=[
#             BoolEq(
#                 class_='BoolEq',
#                 expr1=Access(class_='Access', name='x'),
#                 expr2=MathNum(class_='MathNum', value=1)
#             )
#         ],
#         preds=[27, 26],
#         succs=[29, 30],
#         exit_nodes=[],
#         edge_labels={29: 'true', 30: 'false'}
#     ),
#     29: CFGBlock(
#         register_id=29,
#         stmts=[
#             Evolve(
#                 class_='Evolve',
#                 hamiltonian=Access(class_='Access', name='H_single'),
#                 duration=MathNum(class_='MathNum', value=1.0),
#                 targets=Extract(class_='Extract', access=Access(class_='Access', name='r'), index=0)
#             )
#         ],
#         preds=[28],
#         succs=[31],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     30: CFGBlock(
#         register_id=30,
#         stmts=[
#             Evolve(
#                 class_='Evolve',
#                 hamiltonian=Access(class_='Access', name='H_pair'),
#                 duration=MathNum(class_='MathNum', value=0.5),
#                 targets=Access(class_='Access', name='r')
#             )
#         ],
#         preds=[28],
#         succs=[31],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     31: CFGBlock(
#         register_id=31,
#         stmts=[Declaration(class_='Declaration', name='n', value=MathNum(class_='MathNum', value=3))],
#         preds=[29, 30],
#         succs=[32],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     32: CFGBlock(
#         register_id=32,
#         stmts=[
#             BoolGreaterThan(
#                 class_='BoolGreaterThan',
#                 expr1=Access(class_='Access', name='n'),
#                 expr2=MathNum(class_='MathNum', value=0)
#             )
#         ],
#         preds=[31, 33],
#         succs=[33, 35],
#         exit_nodes=[],
#         edge_labels={33: 'true', 35: 'false'}
#     ),
#     33: CFGBlock(
#         register_id=33,
#         stmts=[
#             Evolve(
#                 class_='Evolve',
#                 hamiltonian=Access(class_='Access', name='H_rabi'),
#                 duration=MathNum(class_='MathNum', value=0.1),
#                 targets=Access(class_='Access', name='targets')
#             ),
#             Declaration(
#                 class_='Declaration',
#                 name='n',
#                 value=MathSub(
#                     class_='MathSub',
#                     expr1=Access(class_='Access', name='n'),
#                     expr2=MathNum(class_='MathNum', value=1)
#                 )
#             )
#         ],
#         preds=[32],
#         succs=[32],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     35: CFGBlock(
#         register_id=35,
#         stmts=[Bool(class_='Bool', value=True)],
#         preds=[32, 36],
#         succs=[36, 38],
#         exit_nodes=[37],
#         edge_labels={36: 'true', 38: 'false'}
#     ),
#     36: CFGBlock(
#         register_id=36,
#         stmts=[
#             BoolEq(
#                 class_='BoolEq',
#                 expr1=Access(class_='Access', name='x'),
#                 expr2=MathNum(class_='MathNum', value=1)
#             )
#         ],
#         preds=[35],
#         succs=[37, 35],
#         exit_nodes=[],
#         edge_labels={37: 'true', 35: 'false'}
#     ),
#     37: CFGBlock(
#         register_id=37,
#         stmts=[Break(class_='Break')],
#         preds=[36],
#         succs=[38],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     38: CFGBlock(
#         register_id=38,
#         stmts=[
#             Declaration(class_='Declaration', name='a', value=MathNum(class_='MathNum', value=5)),
#             Declaration(class_='Declaration', name='b', value=MathNum(class_='MathNum', value=3))
#         ],
#         preds=[37, 35],
#         succs=[40],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     40: CFGBlock(
#         register_id=40,
#         stmts=[
#             BoolGreaterThan(
#                 class_='BoolGreaterThan',
#                 expr1=Access(class_='Access', name='a'),
#                 expr2=Access(class_='Access', name='b')
#             )
#         ],
#         preds=[38],
#         succs=[41, 44],
#         exit_nodes=[],
#         edge_labels={41: 'true', 44: 'false'}
#     ),
#     41: CFGBlock(
#         register_id=41,
#         stmts=[
#             BoolGreaterThan(
#                 class_='BoolGreaterThan',
#                 expr1=Access(class_='Access', name='b'),
#                 expr2=MathNum(class_='MathNum', value=0)
#             )
#         ],
#         preds=[40],
#         succs=[42, 43],
#         exit_nodes=[],
#         edge_labels={42: 'true', 43: 'false'}
#     ),
#     42: CFGBlock(
#         register_id=42,
#         stmts=[Initialize(class_='Initialize', targets=Access(class_='Access', name='targets'))],
#         preds=[41],
#         succs=[44],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     43: CFGBlock(
#         register_id=43,
#         stmts=[Measure(class_='Measure', targets=Access(class_='Access', name='r'))],
#         preds=[41],
#         succs=[44],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     44: CFGBlock(
#         register_id=44,
#         stmts=[
#             Initialize(class_='Initialize', targets=Access(class_='Access', name='r')),
#             Evolve(
#                 class_='Evolve',
#                 hamiltonian=Access(class_='Access', name='H_single'),
#                 duration=MathNum(class_='MathNum', value=2.0),
#                 targets=Access(class_='Access', name='q1')
#             ),
#             Evolve(
#                 class_='Evolve',
#                 hamiltonian=Access(class_='Access', name='H_pair'),
#                 duration=MathNum(class_='MathNum', value=1.0),
#                 targets=Access(class_='Access', name='targets')
#             ),
#             Evolve(
#                 class_='Evolve',
#                 hamiltonian=OperatorMul(
#                     class_='OperatorMul',
#                     op1=PauliX(class_='PauliX'),
#                     op2=MathNum(class_='MathNum', value=0.5)
#                 ),
#                 duration=Access(class_='Access', name='pi'),
#                 targets=Access(class_='Access', name='q0')
#             ),
#             Measure(class_='Measure', targets=Access(class_='Access', name='r')),
#             Declaration(
#                 class_='Declaration',
#                 name='measurement',
#                 value=Measure(class_='Measure', targets=Access(class_='Access', name='q0'))
#             ),
#             Declaration(class_='Declaration', name='flag', value=MathNum(class_='MathNum', value=1))
#         ],
#         preds=[42, 43, 40],
#         succs=[51],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     51: CFGBlock(
#         register_id=51,
#         stmts=[
#             BoolNotEq(
#                 class_='BoolNotEq',
#                 expr1=Access(class_='Access', name='flag'),
#                 expr2=MathNum(class_='MathNum', value=0)
#             )
#         ],
#         preds=[44],
#         succs=[52, 53],
#         exit_nodes=[],
#         edge_labels={52: 'true', 53: 'false'}
#     ),
#     52: CFGBlock(
#         register_id=52,
#         stmts=[Declaration(class_='Declaration', name='x', value=MathNum(class_='MathNum', value=0))],
#         preds=[51],
#         succs=[53],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     53: CFGBlock(
#         register_id=53,
#         stmts=[
#             BoolLessThanEq(
#                 class_='BoolLessThanEq',
#                 expr1=Access(class_='Access', name='x'),
#                 expr2=MathNum(class_='MathNum', value=1)
#             )
#         ],
#         preds=[52, 51],
#         succs=[54, 55],
#         exit_nodes=[],
#         edge_labels={54: 'true', 55: 'false'}
#     ),
#     54: CFGBlock(
#         register_id=54,
#         stmts=[Declaration(class_='Declaration', name='x', value=MathNum(class_='MathNum', value=1))],
#         preds=[53],
#         succs=[55],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     55: CFGBlock(
#         register_id=55,
#         stmts=[
#             BoolGreaterThanEq(
#                 class_='BoolGreaterThanEq',
#                 expr1=Access(class_='Access', name='x'),
#                 expr2=MathNum(class_='MathNum', value=0)
#             )
#         ],
#         preds=[54, 53],
#         succs=[56, 57],
#         exit_nodes=[],
#         edge_labels={56: 'true', 57: 'false'}
#     ),
#     56: CFGBlock(
#         register_id=56,
#         stmts=[Declaration(class_='Declaration', name='x', value=MathNum(class_='MathNum', value=0))],
#         preds=[55],
#         succs=[57],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     57: CFGBlock(
#         register_id=57,
#         stmts=[Declaration(class_='Declaration', name='a', value=Bool(class_='Bool', value=True))],
#         preds=[56, 55],
#         succs=[58],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     58: CFGBlock(
#         register_id=58,
#         stmts=[Access(class_='Access', name='a')],
#         preds=[57],
#         succs=[59, 60],
#         exit_nodes=[],
#         edge_labels={59: 'true', 60: 'false'}
#     ),
#     59: CFGBlock(
#         register_id=59,
#         stmts=[Declaration(class_='Declaration', name='b', value=MathNum(class_='MathNum', value=5))],
#         preds=[58],
#         succs=[60],
#         exit_nodes=[],
#         edge_labels={}
#     ),
#     60: CFGBlock(register_id=60, stmts=[], preds=[59, 58], succs=[], exit_nodes=[], edge_labels={})
# }

# %%
from oqd_compiler_infrastructure import cfg_to_dot

from oqd_core.frontend.analog import serialize_analog

dot = cfg_to_dot(cfg, serialize=serialize_analog, max_lines=3)
print(dot.source)
dot.render("cfg", format="png", cleanup=True)
# Out:
# digraph {
# 	0 [label=" Block #0
# ------------------------
# "]
# 	0 -> 1
# 	1 [label=" Block #1
# ------------------------
# r = qreg(2)
# s = qmode(3)
# q0 = r[0]
# ..."]
# 	1 -> 26
# 	26 [label="Branch Block #26
# ------------------------
# Condition: x > 0"]
# 	26 -> 27
# 	26 -> 28
# 	27 [label=" Block #27
# ------------------------
# initialize(r)"]
# 	27 -> 28
# 	28 [label="Branch Block #28
# ------------------------
# Condition: x == 1"]
# 	28 -> 29
# 	28 -> 30
# 	29 [label=" Block #29
# ------------------------
# evolve(H_single, 1.0, r[0])"]
# 	29 -> 31
# 	30 [label=" Block #30
# ------------------------
# evolve(H_pair, 0.5, r)"]
# 	30 -> 31
# 	31 [label=" Block #31
# ------------------------
# n = 3"]
# 	31 -> 32
# 	32 [label="Branch Block #32
# ------------------------
# Condition: n > 0"]
# 	32 -> 33
# 	32 -> 35
# 	33 [label=" Block #33
# ------------------------
# evolve(H_rabi, 0.1, targets)
# n = n - 1"]
# 	33 -> 32
# 	35 [label="Branch Block #35
# ------------------------
# Condition: true"]
# 	35 -> 36
# 	35 -> 38
# 	36 [label="Branch Block #36
# ------------------------
# Condition: x == 1"]
# 	36 -> 37
# 	36 -> 35
# 	37 [label=" Block #37
# ------------------------
# break"]
# 	37 -> 38
# 	38 [label=" Block #38
# ------------------------
# a = 5
# b = 3"]
# 	38 -> 40
# 	40 [label="Branch Block #40
# ------------------------
# Condition: a > b"]
# 	40 -> 41
# 	40 -> 44
# 	41 [label="Branch Block #41
# ------------------------
# Condition: b > 0"]
# 	41 -> 42
# 	41 -> 43
# 	42 [label=" Block #42
# ------------------------
# initialize(targets)"]
# 	42 -> 44
# 	43 [label=" Block #43
# ------------------------
# measure(r)"]
# 	43 -> 44
# 	44 [label=" Block #44
# ------------------------
# initialize(r)
# evolve(H_single, 2.0, q1)
# evolve(H_pair, 1.0, targets)
# ..."]
# 	44 -> 51
# 	51 [label="Branch Block #51
# ------------------------
# Condition: flag != 0"]
# 	51 -> 52
# 	51 -> 53
# 	52 [label=" Block #52
# ------------------------
# x = 0"]
# 	52 -> 53
# 	53 [label="Branch Block #53
# ------------------------
# Condition: x <= 1"]
# 	53 -> 54
# 	53 -> 55
# 	54 [label=" Block #54
# ------------------------
# x = 1"]
# 	54 -> 55
# 	55 [label="Branch Block #55
# ------------------------
# Condition: x >= 0"]
# 	55 -> 56
# 	55 -> 57
# 	56 [label=" Block #56
# ------------------------
# x = 0"]
# 	56 -> 57
# 	57 [label=" Block #57
# ------------------------
# a = true"]
# 	57 -> 58
# 	58 [label="Branch Block #58
# ------------------------
# Condition: a"]
# 	58 -> 59
# 	58 -> 60
# 	59 [label=" Block #59
# ------------------------
# b = 5"]
# 	59 -> 60
# 	60 [label=" Block #60
# ------------------------
# "]
# }
# 'cfg.png'
